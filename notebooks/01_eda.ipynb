# %% [markdown]
# # CS Prophet — Exploratory Data Analysis
#
# Explore parsed demo data and prototype feature ideas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

DATA_DIR = Path('../data/processed')
